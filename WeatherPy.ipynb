# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# save api_keys information:
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}&units={units}&appid={weather_api_key}&q="

# %%
# Performing a weather check on city using a series of API calls:

# Setting list for the loop call:
city_data = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []


# Print to logger:
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Creating counters for printing log:
record_count = 1
set_count = 1


# Looping through all the cities in our list and performing a request:
for i, city in enumerate(cities):
       
    # Create the endpoint query_url with each city:
    city_url = query_url + city
    
    
    # Grouping cities in sets of 50 for with counters we set for printing log:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
      
    # Printing records with set numbers and counters:
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Adding 1 to the record count for printing:
    record_count += 1

    # Running the API request for each of the cities 
    # (Using try & except)
    try:
        
        # Make request and store in json
        response = requests.get(city_url).json()
        
        
        city_data.append(response["name"])
        city_lat.append(response["coord"]["lat"])
        city_lng.append(response["coord"]["lon"])
        city_max_temp.append(response["main"]["temp_max"])
        city_humidity.append(response["main"]["humidity"])
        city_clouds.append(response["clouds"]["all"])
        city_wind.append(response["wind"]["speed"])
        city_country.append(response["sys"]["country"])
        city_date.append(response["dt"])
        
        # Suspension time to prevent api from getting locked
        time.sleep(2)
        
    # Handle exceptions for experienced error, skip the city:
    except:
        # Append null values
        print("City not found. Skipping...")
        pass 
    
# Include a print log of each city as it'sbeing processed (with the city number and city name)              
# Print when data loading is complete: 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yarmouth
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | faya
# Processing Record 4 of Set 1 | warri
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | shalinskoye
# Processing Record 11 of Set 1 | hailey
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kieta
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | koumac
# Processing Record 17 of Set 1 | pangody
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | carlisle
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | tuatapere
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | krutinka
# Processing Record 28 of Set 1 | kaeo
# Processing Record 29 of Set 1 | sandwick
# Processing Record 30 of Set 1 | alta floresta
# Processing Record 31 of Set 1 | viedma
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | matara
# Processing Record 35 of Set 1 | teguldet
# Processing Record 36 of Set 1 | marawi
# Processing Record 37 of Set 1 | ilhabela
# Processing Record 38 of Set 1 | dubbo
# Processing Record 39 of Set 1 | lata
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | joensuu
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | bowen
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | raudeberg
# Processing Record 49 of Set 1 | fairbanks
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | najran
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | mogadishu
# Processing Record 5 of Set 2 | altyn-topkan
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | arman
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | hami
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | sinnamary
# Processing Record 13 of Set 2 | talaya
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | faanui
# Processing Record 17 of Set 2 | minot
# Processing Record 18 of Set 2 | san andres
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | tecoanapa
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | mikhaylovskoye
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | homer
# Processing Record 29 of Set 2 | anloga
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | las lomas
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | conceicao do mato dentro
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | codrington
# Processing Record 37 of Set 2 | ligayan
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | san quintin
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | novobirilyussy
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 0 of Set 3 | nacala
# Processing Record 1 of Set 3 | margate
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 3 | tekax
# City not found. Skipping...
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | vila franca do campo
# Processing Record 9 of Set 3 | nicoya
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 3 | nantucket
# Processing Record 14 of Set 3 | winnemucca
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | constitucion
# Processing Record 17 of Set 3 | changying
# Processing Record 18 of Set 3 | tazovskiy
# Processing Record 19 of Set 3 | mukhen
# Processing Record 20 of Set 3 | lasem
# Processing Record 21 of Set 3 | teya
# Processing Record 22 of Set 3 | cambui
# Processing Record 23 of Set 3 | husavik
# Processing Record 24 of Set 3 | valparaiso
# Processing Record 25 of Set 3 | harper
# Processing Record 26 of Set 3 | auki
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | am timan
# Processing Record 29 of Set 3 | natal
# Processing Record 30 of Set 3 | kavkazskiy
# Processing Record 31 of Set 3 | san policarpo
# Processing Record 32 of Set 3 | comodoro rivadavia
# Processing Record 33 of Set 3 | gazion
# City not found. Skipping...
# Processing Record 34 of Set 3 | vestmannaeyjar
# Processing Record 35 of Set 3 | westport
# Processing Record 36 of Set 3 | kuryk
# Processing Record 37 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 3 | laguna
# Processing Record 39 of Set 3 | monte escobedo
# Processing Record 40 of Set 3 | channel-port aux basques
# Processing Record 41 of Set 3 | ucluelet
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | chara
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | iquitos
# Processing Record 46 of Set 3 | owo
# Processing Record 47 of Set 3 | christchurch
# Processing Record 48 of Set 3 | abonnema
# Processing Record 49 of Set 3 | muros
# Processing Record 0 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | san pedro
# Processing Record 2 of Set 4 | kashi
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | yanam
# Processing Record 5 of Set 4 | canutama
# Processing Record 6 of Set 4 | rosarito
# Processing Record 7 of Set 4 | griffith
# Processing Record 8 of Set 4 | elliot lake
# Processing Record 9 of Set 4 | alexandria
# Processing Record 10 of Set 4 | rio grande
# Processing Record 11 of Set 4 | fukue
# Processing Record 12 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 4 | maniwaki
# Processing Record 14 of Set 4 | cherskiy
# Processing Record 15 of Set 4 | byron bay
# Processing Record 16 of Set 4 | rawson
# Processing Record 17 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | oranjemund
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | nhulunbuy
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | akcaabat
# Processing Record 24 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 25 of Set 4 | high level
# Processing Record 26 of Set 4 | karratha
# Processing Record 27 of Set 4 | sur
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | yarada
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | suchedniow
# Processing Record 32 of Set 4 | lagoa
# Processing Record 33 of Set 4 | curup
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | gat
# Processing Record 36 of Set 4 | cap malheureux
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | yumen
# Processing Record 39 of Set 4 | batetskiy
# Processing Record 40 of Set 4 | turbana
# Processing Record 41 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 4 | san ramon
# Processing Record 43 of Set 4 | matamoros
# Processing Record 44 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 4 | praia
# Processing Record 46 of Set 4 | urdoma
# Processing Record 47 of Set 4 | eyl
# Processing Record 48 of Set 4 | santa maria
# Processing Record 49 of Set 4 | grand island
# Processing Record 0 of Set 5 | yar-sale
# Processing Record 1 of Set 5 | aksu
# Processing Record 2 of Set 5 | sarila
# Processing Record 3 of Set 5 | mehamn
# Processing Record 4 of Set 5 | evensk
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | kemptville
# Processing Record 7 of Set 5 | east haddam
# Processing Record 8 of Set 5 | krasnoselkup
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | mackay
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | mayumba
# Processing Record 13 of Set 5 | okha
# Processing Record 14 of Set 5 | marrakesh
# Processing Record 15 of Set 5 | georgetown
# Processing Record 16 of Set 5 | isangel
# Processing Record 17 of Set 5 | cam ranh
# Processing Record 18 of Set 5 | clyde river
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | bengkulu
# Processing Record 21 of Set 5 | ostrovnoy
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | juxian
# City not found. Skipping...
# Processing Record 25 of Set 5 | tigil
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | turukhansk
# Processing Record 28 of Set 5 | baykit
# Processing Record 29 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 5 | altagracia de orituco
# Processing Record 31 of Set 5 | pemba
# Processing Record 32 of Set 5 | sapa
# Processing Record 33 of Set 5 | santa cruz
# Processing Record 34 of Set 5 | nouadhibou
# Processing Record 35 of Set 5 | fallon
# Processing Record 36 of Set 5 | sobolevo
# Processing Record 37 of Set 5 | salalah
# Processing Record 38 of Set 5 | gizo
# Processing Record 39 of Set 5 | mahina
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | skibbereen
# Processing Record 43 of Set 5 | bathsheba
# Processing Record 44 of Set 5 | qaanaaq
# Processing Record 45 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 5 | lubango
# Processing Record 47 of Set 5 | petauke
# Processing Record 48 of Set 5 | lebu
# Processing Record 49 of Set 5 | flin flon
# Processing Record 0 of Set 6 | chapais
# Processing Record 1 of Set 6 | talara
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | boguchany
# Processing Record 4 of Set 6 | oussouye
# Processing Record 5 of Set 6 | asfi
# Processing Record 6 of Set 6 | capitola
# Processing Record 7 of Set 6 | tomatlan
# Processing Record 8 of Set 6 | benjamin aceval
# Processing Record 9 of Set 6 | pokhara
# Processing Record 10 of Set 6 | bambous virieux
# Processing Record 11 of Set 6 | hilo
# Processing Record 12 of Set 6 | nadym
# Processing Record 13 of Set 6 | san jeronimo
# Processing Record 14 of Set 6 | el cobre
# Processing Record 15 of Set 6 | neiafu
# Processing Record 16 of Set 6 | alyangula
# Processing Record 17 of Set 6 | yinchuan
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | villach
# Processing Record 20 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 21 of Set 6 | luderitz
# Processing Record 22 of Set 6 | khani
# Processing Record 23 of Set 6 | meadow lake
# Processing Record 24 of Set 6 | esmeraldas
# Processing Record 25 of Set 6 | lloro
# Processing Record 26 of Set 6 | kandrian
# Processing Record 27 of Set 6 | puri
# Processing Record 28 of Set 6 | madaoua
# Processing Record 29 of Set 6 | svetlyy
# Processing Record 30 of Set 6 | maura
# Processing Record 31 of Set 6 | atbasar
# Processing Record 32 of Set 6 | amuntai
# Processing Record 33 of Set 6 | puerto escondido
# Processing Record 34 of Set 6 | thompson
# Processing Record 35 of Set 6 | sovetskiy
# Processing Record 36 of Set 6 | asyut
# Processing Record 37 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 6 | calabozo
# Processing Record 40 of Set 6 | takoradi
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | the pas
# Processing Record 44 of Set 6 | gossas
# Processing Record 45 of Set 6 | kudahuvadhoo
# Processing Record 46 of Set 6 | port elizabeth
# Processing Record 47 of Set 6 | hamilton
# Processing Record 48 of Set 6 | moroni
# Processing Record 49 of Set 6 | deputatskiy
# Processing Record 0 of Set 7 | afareaitu
# Processing Record 1 of Set 7 | port hedland
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | huejuquilla el alto
# Processing Record 4 of Set 7 | sturgeon falls
# Processing Record 5 of Set 7 | beringovskiy
# Processing Record 6 of Set 7 | ballina
# Processing Record 7 of Set 7 | vao
# Processing Record 8 of Set 7 | haines junction
# Processing Record 9 of Set 7 | libertador general san martin
# Processing Record 10 of Set 7 | dapdap
# Processing Record 11 of Set 7 | mount isa
# Processing Record 12 of Set 7 | boatlaname
# City not found. Skipping...
# Processing Record 13 of Set 7 | dakar
# Processing Record 14 of Set 7 | kharp
# Processing Record 15 of Set 7 | mushie
# Processing Record 16 of Set 7 | mattru
# Processing Record 17 of Set 7 | namatanai
# Processing Record 18 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 7 | yeniseysk
# Processing Record 20 of Set 7 | port shepstone
# Processing Record 21 of Set 7 | hervey bay
# Processing Record 22 of Set 7 | quang ngai
# Processing Record 23 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 7 | grindavik
# Processing Record 25 of Set 7 | chokurdakh
# Processing Record 26 of Set 7 | sambava
# Processing Record 27 of Set 7 | eureka
# Processing Record 28 of Set 7 | conde
# Processing Record 29 of Set 7 | ilesha
# Processing Record 30 of Set 7 | porto seguro
# Processing Record 31 of Set 7 | hobyo
# Processing Record 32 of Set 7 | boende
# Processing Record 33 of Set 7 | ha tinh
# Processing Record 34 of Set 7 | asau
# Processing Record 35 of Set 7 | calamar
# Processing Record 36 of Set 7 | longyearbyen
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | coolum beach
# Processing Record 39 of Set 7 | carutapera
# Processing Record 40 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 41 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 42 of Set 7 | uige
# Processing Record 43 of Set 7 | biak
# Processing Record 44 of Set 7 | road town
# Processing Record 45 of Set 7 | jiaonan
# Processing Record 46 of Set 7 | turka
# Processing Record 47 of Set 7 | riviere-au-renard
# Processing Record 48 of Set 7 | lavrentiya
# Processing Record 49 of Set 7 | marshall
# Processing Record 0 of Set 8 | aksarka
# Processing Record 1 of Set 8 | cabo san lucas
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 8 | villa florida
# Processing Record 5 of Set 8 | oktyabrskiy
# Processing Record 6 of Set 8 | kaitangata
# Processing Record 7 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 8 | shitanjing
# Processing Record 9 of Set 8 | cachoeira do sul
# Processing Record 10 of Set 8 | sao joao da barra
# Processing Record 11 of Set 8 | goderich
# Processing Record 12 of Set 8 | playa vicente
# Processing Record 13 of Set 8 | seoul
# Processing Record 14 of Set 8 | kirando
# Processing Record 15 of Set 8 | spetsai
# City not found. Skipping...
# Processing Record 16 of Set 8 | khandyga
# Processing Record 17 of Set 8 | kapit
# Processing Record 18 of Set 8 | balky
# Processing Record 19 of Set 8 | katherine
# Processing Record 20 of Set 8 | myanaung
# Processing Record 21 of Set 8 | maldonado
# Processing Record 22 of Set 8 | fort-shevchenko
# Processing Record 23 of Set 8 | brest
# Processing Record 24 of Set 8 | tokur
# Processing Record 25 of Set 8 | naugarzan
# City not found. Skipping...
# Processing Record 26 of Set 8 | farafangana
# Processing Record 27 of Set 8 | itarema
# Processing Record 28 of Set 8 | kurilsk
# Processing Record 29 of Set 8 | yima
# Processing Record 30 of Set 8 | khandwa
# Processing Record 31 of Set 8 | abay
# Processing Record 32 of Set 8 | nagato
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | kamenka
# Processing Record 35 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 8 | richards bay
# Processing Record 37 of Set 8 | la ronge
# Processing Record 38 of Set 8 | saint anthony
# Processing Record 39 of Set 8 | kampot
# Processing Record 40 of Set 8 | naryan-mar
# Processing Record 41 of Set 8 | oga
# Processing Record 42 of Set 8 | zarand
# Processing Record 43 of Set 8 | ust-kut
# Processing Record 44 of Set 8 | alpena
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | santiago
# Processing Record 47 of Set 8 | baruun-urt
# Processing Record 48 of Set 8 | mulege
# Processing Record 49 of Set 8 | manyana
# Processing Record 0 of Set 9 | felanitx
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | pangnirtung
# Processing Record 3 of Set 9 | lodwar
# Processing Record 4 of Set 9 | birjand
# Processing Record 5 of Set 9 | mitsamiouli
# Processing Record 6 of Set 9 | xingyi
# Processing Record 7 of Set 9 | sabha
# Processing Record 8 of Set 9 | samarai
# Processing Record 9 of Set 9 | cabedelo
# Processing Record 10 of Set 9 | sao filipe
# Processing Record 11 of Set 9 | paka
# Processing Record 12 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 9 | zhanakorgan
# Processing Record 14 of Set 9 | bloomington
# Processing Record 15 of Set 9 | nieves
# Processing Record 16 of Set 9 | lodja
# Processing Record 17 of Set 9 | sabang
# Processing Record 18 of Set 9 | saint-augustin
# Processing Record 19 of Set 9 | brigantine
# Processing Record 20 of Set 9 | vestmanna
# Processing Record 21 of Set 9 | chadiza
# Processing Record 22 of Set 9 | portage
# Processing Record 23 of Set 9 | villa del rosario
# Processing Record 24 of Set 9 | gavle
# Processing Record 25 of Set 9 | belaya gora
# Processing Record 26 of Set 9 | merauke
# Processing Record 27 of Set 9 | surt
# Processing Record 28 of Set 9 | tanout
# Processing Record 29 of Set 9 | upernavik
# Processing Record 30 of Set 9 | mujiayingzi
# Processing Record 31 of Set 9 | floro
# Processing Record 32 of Set 9 | xining
# Processing Record 33 of Set 9 | tiksi
# Processing Record 34 of Set 9 | san jose
# Processing Record 35 of Set 9 | puquio
# Processing Record 36 of Set 9 | camocim
# Processing Record 37 of Set 9 | kapuskasing
# Processing Record 38 of Set 9 | bolshaya sosnova
# Processing Record 39 of Set 9 | padang
# Processing Record 40 of Set 9 | beloha
# Processing Record 41 of Set 9 | sulechow
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | bykovo
# Processing Record 44 of Set 9 | golden
# Processing Record 45 of Set 9 | tiznit
# Processing Record 46 of Set 9 | sjenica
# Processing Record 47 of Set 9 | bahia honda
# Processing Record 48 of Set 9 | atar
# Processing Record 49 of Set 9 | hasaki
# Processing Record 0 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 10 | maceio
# Processing Record 2 of Set 10 | ishimbay
# Processing Record 3 of Set 10 | los llanos de aridane
# Processing Record 4 of Set 10 | tasiilaq
# Processing Record 5 of Set 10 | alofi
# Processing Record 6 of Set 10 | jining
# Processing Record 7 of Set 10 | farafenni
# Processing Record 8 of Set 10 | mindelo
# Processing Record 9 of Set 10 | medea
# Processing Record 10 of Set 10 | korla
# Processing Record 11 of Set 10 | port hawkesbury
# Processing Record 12 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 10 | nuevitas
# Processing Record 14 of Set 10 | ixtapa
# Processing Record 15 of Set 10 | cervo
# Processing Record 16 of Set 10 | jiaocheng
# Processing Record 17 of Set 10 | tilichiki
# Processing Record 18 of Set 10 | narsaq
# Processing Record 19 of Set 10 | santa isabel do rio negro
# Processing Record 20 of Set 10 | hofn
# Processing Record 21 of Set 10 | siderno
# Processing Record 22 of Set 10 | sioux lookout
# Processing Record 23 of Set 10 | cockburn town
# Processing Record 24 of Set 10 | vila do maio
# Processing Record 25 of Set 10 | chabahar
# Processing Record 26 of Set 10 | pueblo nuevo
# Processing Record 27 of Set 10 | muscatine
# Processing Record 28 of Set 10 | ambilobe
# Processing Record 29 of Set 10 | tongzi
# Processing Record 30 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 10 | te anau
# Processing Record 32 of Set 10 | podhum
# Processing Record 33 of Set 10 | seoni malwa
# Processing Record 34 of Set 10 | shaunavon
# Processing Record 35 of Set 10 | coihaique
# Processing Record 36 of Set 10 | neryungri
# Processing Record 37 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 10 | fuling
# Processing Record 39 of Set 10 | isilkul
# Processing Record 40 of Set 10 | talnakh
# Processing Record 41 of Set 10 | daphne
# Processing Record 42 of Set 10 | sandviken
# Processing Record 43 of Set 10 | palimbang
# Processing Record 44 of Set 10 | veraval
# Processing Record 45 of Set 10 | bucerias
# Processing Record 46 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 10 | solano
# Processing Record 48 of Set 10 | abashiri
# Processing Record 49 of Set 10 | caceres
# Processing Record 0 of Set 11 | port macquarie
# Processing Record 1 of Set 11 | manchester
# Processing Record 2 of Set 11 | luanda
# Processing Record 3 of Set 11 | watrous
# Processing Record 4 of Set 11 | sitka
# Processing Record 5 of Set 11 | roald
# Processing Record 6 of Set 11 | dawlatabad
# Processing Record 7 of Set 11 | sivaki
# Processing Record 8 of Set 11 | sarangani
# Processing Record 9 of Set 11 | bayanday
# Processing Record 10 of Set 11 | shu
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | cururupu
# Processing Record 13 of Set 11 | lagos
# Processing Record 14 of Set 11 | rumia
# Processing Record 15 of Set 11 | petatlan
# Processing Record 16 of Set 11 | hualmay
# Processing Record 17 of Set 11 | arnprior
# Processing Record 18 of Set 11 | antigonish
# Processing Record 19 of Set 11 | marystown
# Processing Record 20 of Set 11 | wamba
# Processing Record 21 of Set 11 | porto belo
# Processing Record 22 of Set 11 | callaway
# Processing Record 23 of Set 11 | uusikaupunki
# Processing Record 24 of Set 11 | lakes entrance
# Processing Record 25 of Set 11 | aswan
# Processing Record 26 of Set 11 | energeticheskiy
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | cidreira
# Processing Record 29 of Set 11 | akyab
# Processing Record 30 of Set 11 | chodavaram
# Processing Record 31 of Set 11 | aktash
# Processing Record 32 of Set 11 | le port
# Processing Record 33 of Set 11 | kerema
# Processing Record 34 of Set 11 | grand bank
# Processing Record 35 of Set 11 | great yarmouth
# Processing Record 36 of Set 11 | labuhan
# Processing Record 37 of Set 11 | pangai
# Processing Record 38 of Set 11 | malabo
# Processing Record 39 of Set 11 | lagawe
# Processing Record 40 of Set 11 | komsomolskiy
# Processing Record 41 of Set 11 | belmonte
# Processing Record 42 of Set 11 | vangaindrano
# Processing Record 43 of Set 11 | tezu
# Processing Record 44 of Set 11 | champerico
# Processing Record 45 of Set 11 | waingapu
# Processing Record 46 of Set 11 | kalmunai
# Processing Record 47 of Set 11 | tambovka
# Processing Record 48 of Set 11 | broome
# Processing Record 49 of Set 11 | mareeba
# Processing Record 0 of Set 12 | poya
# Processing Record 1 of Set 12 | panguna
# Processing Record 2 of Set 12 | kinablangan
# Processing Record 3 of Set 12 | southport
# Processing Record 4 of Set 12 | uyemskiy
# Processing Record 5 of Set 12 | klerksdorp
# Processing Record 6 of Set 12 | mendoza
# Processing Record 7 of Set 12 | verkhoyansk
# Processing Record 8 of Set 12 | vikulovo
# Processing Record 9 of Set 12 | floriano
# Processing Record 10 of Set 12 | mehran
# Processing Record 11 of Set 12 | plouzane
# Processing Record 12 of Set 12 | dryden
# Processing Record 13 of Set 12 | grand gaube
# Processing Record 14 of Set 12 | olafsvik
# Processing Record 15 of Set 12 | mocuba
# Processing Record 16 of Set 12 | kushtagi
# Processing Record 17 of Set 12 | seminole
# Processing Record 18 of Set 12 | elko
# Processing Record 19 of Set 12 | coahuayana
# Processing Record 20 of Set 12 | shetpe
# Processing Record 21 of Set 12 | victor harbor
# Processing Record 22 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 23 of Set 12 | sungurlu
# Processing Record 24 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 12 | cairns
# Processing Record 26 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 12 | humaita
# Processing Record 28 of Set 12 | abu samrah
# Processing Record 29 of Set 12 | puerto madryn
# Processing Record 30 of Set 12 | walvis bay
# Processing Record 31 of Set 12 | saquena
# Processing Record 32 of Set 12 | tiarei
# Processing Record 33 of Set 12 | honningsvag
# Processing Record 34 of Set 12 | vanavara
# Processing Record 35 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 12 | mamallapuram
# Processing Record 38 of Set 12 | kumluca
# Processing Record 39 of Set 12 | lyngseidet
# Processing Record 40 of Set 12 | nongan
# Processing Record 41 of Set 12 | varca
# Processing Record 42 of Set 12 | sirsi
# Processing Record 43 of Set 12 | tura
# Processing Record 44 of Set 12 | tuy hoa
# Processing Record 45 of Set 12 | sunnyside
# Processing Record 46 of Set 12 | balabac
# Processing Record 47 of Set 12 | kirkwall
# Processing Record 48 of Set 12 | pinotepa nacional
# Processing Record 49 of Set 12 | quatre cocos
# Processing Record 0 of Set 13 | sorland
# Processing Record 1 of Set 13 | kloulklubed
# Processing Record 2 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 13 | krasnaya gora
# Processing Record 4 of Set 13 | yeppoon
# Processing Record 5 of Set 13 | aklavik
# Processing Record 6 of Set 13 | turayf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Creating new dataframe for cities data:
city_data_df ={
    "City": city_data, 
    "Lat": city_lat, 
    "Lng": city_lng, 
    "Max Temp": city_max_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind Speed": city_wind,
    "Country": city_country,
     "Date": city_date}

weather_df = pd.DataFrame(city_data_df)
weather_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
weather_df.head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Yarmouth  41.7057 -70.2286     71.19        79           1       13.00
# 1   Ilulissat  69.2167 -51.1000     26.62        31           0       12.66
# 2        Faya  18.3851  42.4509     62.71        23          70        5.14
# 3       Warri   5.5167   5.7500     74.61        92          60        3.78
# 4  Nikolskoye  59.7035  30.7861     45.01        95           0        3.06
#
#   Country        Date
# 0      US  1632786575
# 1      GL  1632786329
# 2      SA  1632786579
# 3      NG  1632786582
# 4      RU  1632786460

# %%
weather_df.to_csv("../output_data/city_weather.csv", index=False, header=True)

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean    20.009385   14.778867   64.337074   72.402154   53.655296    7.665925
# std     33.202365   90.784200   16.684783   19.671306   36.574941    5.414729
# min    -54.800000 -175.200000   20.770000    8.000000    0.000000    0.000000
# 25%     -7.608700  -65.102300   53.020000   64.000000   17.000000    3.620000
# 50%     22.285500   18.388000   69.370000   77.000000   60.000000    6.510000
# 75%     47.666600   92.626700   77.880000   86.000000   89.000000   10.310000
# max     78.218600  179.316700   93.630000  100.000000  100.000000   32.280000
#
#                Date
# count  5.570000e+02
# mean   1.632787e+09
# std    3.872163e+02
# min    1.632786e+09
# 25%    1.632787e+09
# 50%    1.632787e+09
# 75%    1.632788e+09
# max    1.632788e+09

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Yarmouth  41.7057 -70.2286     71.19        79           1       13.00
# 1   Ilulissat  69.2167 -51.1000     26.62        31           0       12.66
# 2        Faya  18.3851  42.4509     62.71        23          70        5.14
# 3       Warri   5.5167   5.7500     74.61        92          60        3.78
# 4  Nikolskoye  59.7035  30.7861     45.01        95           0        3.06
#
#   Country        Date
# 0      US  1632786575
# 1      GL  1632786329
# 2      SA  1632786579
# 3      NG  1632786582
# 4      RU  1632786460

# %%
weather_df.loc[weather_df["Humidity"] >= 100]["Humidity"].count()
# Out:
# 6

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
filtered_df = weather_df.loc[weather_df['Humidity'] < 100]
len(filtered_df)
# Out:
# 551

# %%
len(weather_df)

filtered_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  551.000000  551.000000  551.000000  551.000000  551.000000  551.000000
# mean    19.660004   14.986202   64.491851   72.101633   53.586207    7.721234
# std     33.168222   90.994836   16.645573   19.564825   36.627204    5.415192
# min    -54.800000 -175.200000   20.770000    8.000000    0.000000    0.000000
# 25%     -8.033050  -65.407400   53.655000   64.000000   17.000000    3.670000
# 50%     21.833300   18.388000   69.460000   77.000000   60.000000    6.530000
# 75%     47.241650   93.175000   77.980000   85.500000   89.000000   10.360000
# max     78.218600  179.316700   93.630000   99.000000  100.000000   32.280000
#
#                Date
# count  5.510000e+02
# mean   1.632787e+09
# std    3.871125e+02
# min    1.632786e+09
# 25%    1.632787e+09
# 50%    1.632787e+09
# 75%    1.632788e+09
# max    1.632788e+09

# %%
#  Get the indices of cities that have humidity over 100%.
over_100 = weather_df[weather_df.Humidity > 100].index
over_100
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df
for x in over_100:
    clean_city_data = weather_df.drop([x])
clean_city_data
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Yarmouth  41.7057  -70.2286     71.19        79           1
# 1        Ilulissat  69.2167  -51.1000     26.62        31           0
# 2             Faya  18.3851   42.4509     62.71        23          70
# 3            Warri   5.5167    5.7500     74.61        92          60
# 4       Nikolskoye  59.7035   30.7861     45.01        95           0
# ..             ...      ...       ...       ...       ...         ...
# 552    Kloulklubed   7.0419  134.2556     86.50        73          92
# 553  Krasnaya Gora  52.9995   31.6023     41.11        94          16
# 554        Yeppoon -23.1333  150.7333     73.18        65          90
# 555        Aklavik  68.2191 -135.0107     31.21        81           7
# 556         Turaif  31.6725   38.6637     70.72        62           2
#
#      Wind Speed Country        Date
# 0         13.00      US  1632786575
# 1         12.66      GL  1632786329
# 2          5.14      SA  1632786579
# 3          3.78      NG  1632786582
# 4          3.06      RU  1632786460
# ..          ...     ...         ...
# 552        8.14      PW  1632787842
# 553        6.24      RU  1632787844
# 554       15.90      AU  1632787846
# 555        6.82      CA  1632787849
# 556       10.27      SA  1632787851
#
# [557 rows x 9 columns]

# %%
lat = clean_city_data .Lat
max_temp = clean_city_data ["Max Temp"]
humid = clean_city_data.Humidity
cloud = clean_city_data.Cloudiness
wind = clean_city_data['Wind Speed']

# Export the clean_city_data into a csv:
clean_city_data.to_csv("../output_data/clean_city_data.csv", index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title(f"City Latitude v Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid(True)


plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title(f"City Latitude v Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)


plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, wind_speed, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hemisphere = clean_city_data.loc[clean_city_data["Lat"] >= 0]
south_hemisphere = clean_city_data.loc[clean_city_data["Lat"] < 0]
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression: 
x_values = pd.to_numeric(north_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(north_hemisphere['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 1: Northern Hemisphere - Max Temp vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(16,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The p-value is: 1.289489251614086e-110
# The r-value is: -0.8559511843026559

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(south_hemisphere['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 2: Southern Hemisphere - Max Temp vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,45),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")

plt.savefig("../Images/south_temp_lg.png")
plt.show()
# Out:
# The p-value is: 3.028037091900028e-32
# The r-value is: 0.7436658247671744

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = pd.to_numeric(north_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(north_hemisphere['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 3: Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")


plt.show()
# Out:
# The p-value is: 0.6688225781289316
# The r-value is: -0.02198462792666502

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = pd.to_numeric(south_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(south_hemisphere['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 4: Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")


plt.show()
# Out:
# The p-value is: 0.001774814869140195
# The r-value is: 0.2339841357614036

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = pd.to_numeric(north_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(north_hemisphere['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 5: Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")


plt.show()
# Out:
# The p-value is: 0.7067825247266729
# The r-value is: -0.019334049983376133

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression:
x_values = pd.to_numeric(south_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(south_hemisphere['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 6: Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")


plt.show()
# Out:
# The p-value is: 0.010469723333714931
# The r-value is: 0.19252419735344023

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression:
x_values = pd.to_numeric(north_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(north_hemisphere['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 7: Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")

plt.show()
# Out:
# The p-value is: 0.0010028066964320906
# The r-value is: 0.16789219081441423

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression: 
x_values = pd.to_numeric(south_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(south_hemisphere['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot 8: Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

# Calculated pvalue to determine whether correlation is significant(if there is truly a relationship):
print(f"The p-value is: {pvalue}")
print(f"The r-value is: {rvalue}")


plt.show()
# Out:
# The p-value is: 0.006506045214999204
# The r-value is: -0.2043987803240783
